# %% [markdown]
# <a href="https://colab.research.google.com/github/PosgradoMNA/actividades-de-aprendizaje-A01794003/blob/main/Semana_8_Data_Analysis_with_Python_(IBM).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Data Analysis with Python
#
# Juan Carlos Villamil Rojas
# Matricula  A01794003

# %% [markdown]
# ![final.png](data:image/png;base64,...)![4.png](data:image/png;base64,...)

# %% [markdown]
# ![3.png](data:image/png;base64,...)![2.png](data:image/png;base64,...)![1.png](data:image/png;base64,...)
