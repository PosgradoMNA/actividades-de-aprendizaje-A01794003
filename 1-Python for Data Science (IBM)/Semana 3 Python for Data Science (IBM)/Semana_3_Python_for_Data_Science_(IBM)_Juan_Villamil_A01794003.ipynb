# %% [markdown]
# **	Juan Villamil
#  A01794003**

# %% [markdown]
# ![2.png](data:image/png;base64,...)![1.png](data:image/png;base64,...)![4.png](data:image/png;base64,...)![3.png](data:image/png;base64,...)![0.png](data:image/png;base64,...)
