# %% [markdown]
# Semana 1 - Actividad 2: Python for Data Science (IBM)
#
# Juan Carlos Villamil Rojas
# Matricula  A01794003

# %% [markdown]
# ![tec1.png](data:image/png;base64,...)

# %% [markdown]
# ![2.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![3.png](data:image/png;base64,...)

# %% [markdown]
# ![4.png](data:image/png;base64,...)

# %% [markdown]
# ![5.png](data:image/png;base64,...)

# %%
Numbers = "0123456"

"0123456".find('1')
# Out:
# 1

# %%
print (Numbers)
# Out:
# 0123456

# %%
3 + 2 * 2
# Out:
# 7

# %%
name = 'Lizz'
print(name[0:2])
# Out:
# Li

# %%
var = '01234567'
print(var[::2])
# Out:
# 0246

# %%
'1'+'2'
# Out:
# '12'

# %%
myvar = 'hello'

# %%
A=(0,1,2,3)
print(A)
# Out:
# (0, 1, 2, 3)

# %%
a = 'Juan Villamil'
b = a.upper()
c = a.replace('Juan', ' A01794003')
d = a.find('Villamil')
print(a, b, c, d)
# Out:
# Juan Villamil JUAN VILLAMIL  A01794003 Villamil 5

# %%
import sys
print(sys.version)
# Out:
# 3.7.15 (default, Oct 12 2022, 19:14:55)
# [GCC 7.5.0]
